# %%
pip install radvel
# Out:
# ...
#
#   Using cached radvel-1.4.9.tar.gz (79 kB)
#   Preparing metadata (setup.py): started
#   Preparing metadata (setup.py): finished with status 'done'
# ...
#   Using cached Cython-3.0.0-cp311-cp311-win_amd64.whl (2.8 MB)
# ...
#   Using cached corner-2.2.2-py3-none-any.whl (15 kB)
# ...
#   Using cached emcee-3.1.4-py2.py3-none-any.whl (46 kB)
# ...
#   Running setup.py clean for radvel
# Failed to build radvel
#   error: subprocess-exited-with-error
#
#   python setup.py bdist_wheel did not run successfully.
#   exit code: 1
#
#   [100 lines of output]
#   C:\Users\surya\anaconda3\Lib\site-packages\setuptools\__init__.py:84: _DeprecatedInstaller: setuptools.installer and fetch_build_eggs are deprecated.
#   !!
#
#           ********************************************************************************
#           Requirements should be satisfied by a PEP 517 installer.
#           If you are using pip, you can try `pip install --use-pep517`.
# ...
